# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as BS
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_the_busiest_airports_in_the_United_States'
response = requests.get(URL)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.status_code
# Out:
# 200

# %%
soup = BS(response.text)

# %%
soup.find('title')
# Out:
# <title>List of the busiest airports in the United States - Wikipedia</title>

# %%
type(soup.find('title'))
# Out:
# bs4.element.Tag

# %%
soup.find('title').text
# Out:
# 'List of the busiest airports in the United States - Wikipedia'

# %%
chart = soup.find('table',{'class':'wikitable sortable'})
print(type(chart))
# Out:
# <class 'bs4.element.Tag'>

# %%
data = chart.findAll('a')

# %%
large_hubs = pd.DataFrame(pd.read_html(str(soup.find('table', {'class' : 'wikitable sortable'})))[0])
large_hubs
# Out:
#     Rank(2021)                             Airports (large hubs) IATACode  \
# 0            1  Hartsfield–Jackson Atlanta International Airport      ATL
# 1            2           Dallas/Fort Worth International Airport      DFW
# 2            3                      Denver International Airport      DEN
# 3            4                      O'Hare International Airport      ORD
# 4            5                 Los Angeles International Airport      LAX
# 5            6           Charlotte Douglas International Airport      CLT
# 6            7                     Orlando International Airport      MCO
# 7            8                  Harry Reid International Airport      LAS
# 8            9          Phoenix Sky Harbor International Airport      PHX
# 9           10                       Miami International Airport      MIA
# 10          11              Seattle–Tacoma International Airport      SEA
# 11          12              George Bush Intercontinental Airport      IAH
# ...

# %%
#LIST OF LARGE HUB CODES
#large_hub_list =  list(large_hubs["IATACode"])
#large_hub_list

# %%
pb = pd.DataFrame(large_hubs[['Rank(2021)', 'Airports (large hubs)','IATACode','Major cities served', 'State', '2021', '2020[3]', '2019[4]', '2018[5]']]).rename(columns={'2020[3]':'2020', '2019[4]':'2019', '2018[5]': '2018', 'Airports (large hubs)':'Airport', 'Rank(2021)': "Rank"})
pb
# Out:
#     Rank                                           Airport IATACode  \
# 0      1  Hartsfield–Jackson Atlanta International Airport      ATL
# 1      2           Dallas/Fort Worth International Airport      DFW
# 2      3                      Denver International Airport      DEN
# 3      4                      O'Hare International Airport      ORD
# 4      5                 Los Angeles International Airport      LAX
# 5      6           Charlotte Douglas International Airport      CLT
# 6      7                     Orlando International Airport      MCO
# 7      8                  Harry Reid International Airport      LAS
# 8      9          Phoenix Sky Harbor International Airport      PHX
# 9     10                       Miami International Airport      MIA
# 10    11              Seattle–Tacoma International Airport      SEA
# 11    12              George Bush Intercontinental Airport      IAH
# 12    13             John F. Kennedy International Airport      JFK
# ...

# %%
#pb.to_csv('passenger_boardings.csv')
